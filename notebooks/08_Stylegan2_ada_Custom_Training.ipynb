# %% [markdown]
# # Custom Training StyleGan2-ADA
#
# I chose [StyleGAN2-ADA by NVIDA](https://github.com/NVlabs/stylegan2) to generate the images for this tarot deck based on examples I found online and the availability of tutorials and reference materials.
#
# This tutorial by [Derrick Schultz](https://artificial-images.com/) on YouTube was especially helpful and I followed it very closely. I did ended up tweaking some of the training parameters in the `train.py` file, and those notes can be found below.
#
# I'll only be sharing this main notebook used to train and generate images - for the full repo required to run this, please check out [Derrick's forked version of NVIDIA's StyleGAN2-ADA on GitHub](https://github.com/dvschultz/stylegan2-ada).
#
# A word to the wise, training GANs can be an extremely fickle process. I spent the better part of two weeks running this constantly on Google Colab -- running into dead ends, tweaking, re-starting, resuming... For anyone interested in running StyleGAN2, I'd highly recommend paying the $10/month for Colab Pro: you'll get access to faster GPU's and longer run times (up to 20 hours in a session).

# %% [markdown]
# StyleGAN2-ADA only work with Tensorflow 1.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Fri Dec  4 16:50:10 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Install Repo to Google Drive
#
# Installing [Derrick Schultz's version of the StyleGAN2-ADA repo](https://github.com/dvschultz/stylegan2-ada)
#
#
# First, mounting my Google Drive to the Colab notebook:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Installing the repo during the first run of this notebook. Then simply moving into the directory for subsequent trainings.

# %%
import os
if os.path.isdir("/content/drive/My Drive/colab-sg2-ada"):
    # %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
else:
    #install script
    # %cd "/content/drive/My Drive/"
    # !mkdir colab-sg2-ada
    # %cd colab-sg2-ada
    # !git clone https://github.com/dvschultz/stylegan2-ada
    # %cd stylegan2-ada
    # !mkdir downloads
    # !mkdir datasets
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %% [markdown]
# ## Convert dataset to .tfrecords

# %% [markdown]
# **NOTE: Only done when first creating the dataset -- skip when resuming training**
#
# First, unzipping uploaded photos to content folder in Colab

# %%
# unzippng photos loaded into content folder
zip_path = "/content/tarot_512_os_2.zip"

# !unzip {zip_path} -d /content/

# %% [markdown]
# Converting images to the `.tfrecords` format.

# %%
#update this to the path to your image folder
dataset_path = "/content/tarot_512_os_2"
#give your dataset a name
dataset_name = "tarot_os2"

#you don't need to edit anything here
# !python dataset_tool.py create_from_images ./datasets/{dataset_name} {dataset_path}
# Out:
# Loading images from "/content/tarot_512_os_2"
# Creating dataset "./datasets/tarot_os2"
# Added 2978 images.

# %% [markdown]
# ## Train a custom model
#
# We’re ready to start training! There are numerous arguments to training, what’s listed below are the most popular options. To see all the options, run the following cell.

# %%
# !python train.py --help
# Out:
# usage: train.py [-h] --outdir DIR [--gpus INT] [--snap INT] [--seed INT] [-n]
#                 --data PATH [--res INT] [--mirror BOOL] [--mirrory BOOL]
#                 [--use-raw BOOL] [--metrics LIST] [--metricdata PATH]
#                 [--cfg {auto,11gb-gpu,11gb-gpu-complex,24gb-gpu,24gb-gpu-complex,48gb-gpu,stylegan2,paper256,paper512,paper1024,cifar,cifarbaseline}]
#                 [--gamma FLOAT] [--kimg INT] [--aug {noaug,ada,fixed,adarv}]
#                 [--p FLOAT] [--target TARGET]
#                 [--augpipe {blit,geom,color,filter,noise,cutout,bg,bgc,bgcf,bgcfn,bgcfnc}]
#                 [--cmethod {nocmethod,bcr,zcr,pagan,wgangp,auxrot,spectralnorm,shallowmap,adropout}]
#                 [--dcap FLOAT] [--resume RESUME] [--freezed INT]
#
# Train a GAN using the techniques described in the paper
# "Training Generative Adversarial Networks with Limited Data".
#
# optional arguments:
#   -h, --help            show this help message and exit
#
# general options:
#   --outdir DIR          Where to save the results (required)
#   --gpus INT            Number of GPUs to use (default: 1 gpu)
#   --snap INT            Snapshot interval (default: 50 ticks)
#   --seed INT            Random seed (default: 1000)
#   -n, --dry-run         Print training options and exit
#
# training dataset:
#   --data PATH           Training dataset path (required)
#   --res INT             Dataset resolution (default: highest available)
#   --mirror BOOL         Augment dataset with x-flips (default: false)
#   --mirrory BOOL        Augment dataset with y-flips (default: false)
#   --use-raw BOOL        Use raw image dataset, i.e. created from
#                         create_from_images_raw (default: False)
#
# metrics:
#   --metrics LIST        Comma-separated list or "none" (default: fid50k_full)
#   --metricdata PATH     Dataset to evaluate metrics against (optional)
#
# base config:
#   --cfg {auto,11gb-gpu,11gb-gpu-complex,24gb-gpu,24gb-gpu-complex,48gb-gpu,stylegan2,paper256,paper512,paper1024,cifar,cifarbaseline}
#                         Base config (default: auto)
#   --gamma FLOAT         Override R1 gamma
#   --kimg INT            Override training duration
#
# discriminator augmentation:
#   --aug {noaug,ada,fixed,adarv}
#                         Augmentation mode (default: ada)
#   --p FLOAT             Specify augmentation probability for --aug=fixed
#   --target TARGET       Override ADA target for --aug=ada and --aug=adarv
#   --augpipe {blit,geom,color,filter,noise,cutout,bg,bgc,bgcf,bgcfn,bgcfnc}
#                         Augmentation pipeline (default: bgc)
#
# comparison methods:
#   --cmethod {nocmethod,bcr,zcr,pagan,wgangp,auxrot,spectralnorm,shallowmap,adropout}
#                         Comparison method (default: nocmethod)
#   --dcap FLOAT          Multiplier for discriminator capacity
#
# transfer learning:
#   --resume RESUME       Resume from network pickle (default: noresume)
#   --freezed INT         Freeze-D (default: 0 discriminator layers)
#
# examples:
#
#   # Train custom dataset using 1 GPU.
#   python train.py --outdir=~/training-runs --gpus=1 --data=~/datasets/custom
#
#   # Train class-conditional CIFAR-10 using 2 GPUs.
#   python train.py --outdir=~/training-runs --gpus=2 --data=~/datasets/cifar10c \
#       --cfg=cifar
#
#   # Transfer learn MetFaces from FFHQ using 4 GPUs.
#   python train.py --outdir=~/training-runs --gpus=4 --data=~/datasets/metfaces \
#       --cfg=paper1024 --mirror=1 --resume=ffhq1024 --snap=10
#
#   # Reproduce original StyleGAN2 config F.
#   python train.py --outdir=~/training-runs --gpus=8 --data=~/datasets/ffhq \
#       --cfg=stylegan2 --res=1024 --mirror=1 --aug=noaug
#
# available base configs (--cfg):
#   auto           Automatically select reasonable defaults based on resolution
#                  and GPU count. Good starting point for new datasets.
#   stylegan2      Reproduce results for StyleGAN2 config F at 1024x1024.
#   paper256       Reproduce results for FFHQ and LSUN Cat at 256x256.
#   paper512       Reproduce results for BreCaHAD and AFHQ at 512x512.
#   paper1024      Reproduce results for MetFaces at 1024x1024.
#   cifar          Reproduce results for CIFAR-10 (tuned configuration).
#   cifarbaseline  Reproduce results for CIFAR-10 (baseline configuration).
#
# transfer learning source networks (--resume):
#   ffhq256        FFHQ trained at 256x256 resolution.
#   ffhq512        FFHQ trained at 512x512 resolution.
#   ffhq1024       FFHQ trained at 1024x1024 resolution.
#   celebahq256    CelebA-HQ trained at 256x256 resolution.
#   lsundog256     LSUN Dog trained at 256x256 resolution.
#   afhqcat512     AFHQ Cat trained at 512x512 resolution.
#   afhqdog512     AFHQ Dog trained at 512x512 resolution.
#   afhqwild512    AFHQ Wild trained at 512x512 resolution.
#   brecahad512    BreCaHAD trained at 512x512 resolution.
#   cifar10        CIFAR10 trained at 32x32 resolution.
#   metfaces512    MetFaces trained at 512x512 resolution.
#   <path or URL>  Custom network pickle.

# %%
#this name must EXACTLY match the dataset name you used when creating the .tfrecords file
dataset_name = "tarot_os2"
#how often should the model generate samples and a .pkl file
snapshot_count = 4
#should the images be mirrored left to right?
mirrored = True
#should the images be mirrored top to bottom?
mirroredY = False
#metrics? 
metric_list = None
#augments
augs = "bg"
# Gamma
set_gamma = 35.0

#------- Resume From -------#
#
# running it for the first time? set it to ffhq(+resolution)
# resume_from = 'ffhq512'

# resuming? get the path to your latest .pkl file and use that
resume_from = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00020-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"

#don't edit this unless you know what you're doing :)
# !python train.py --outdir ./results --snap={snapshot_count} --cfg=11gb-gpu --data=./datasets/{dataset_name} --augpipe={augs} --mirror={mirrored} --mirrory={mirroredY} --metrics={metric_list} --resume={resume_from} --gamma={set_gamma}
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x7ef8000 @  0x7f6e1d604001 0x7f6e1a82d765 0x7f6e1a891bb0 0x7f6e1a893a4f 0x7f6e1a92a048 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f6c4b420000 @  0x7f6e1d6021e7 0x7f6e1a82d5e1 0x7f6e1a891c78 0x7f6e1a891f37 0x7f6e1a929f28 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f6b4a41e000 @  0x7f6e1d6021e7 0x7f6e1a82d5e1 0x7f6e1a891c78 0x7f6e1a891f37 0x7f6dd88970c5 0x7f6dd821a902 0x7f6dd821aeb2 0x7f6dd81d3c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
#
# Training options:
# {
#   "G_args": {
#     "func_name": "training.networks.G_main",
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "mapping_layers": 8,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "D_args": {
#     "func_name": "training.networks.D_main",
#     "mbstd_group_size": 8,
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.0016
#   },
#   "D_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.0016
#   },
#   "loss_args": {
#     "func_name": "training.loss.stylegan2",
#     "r1_gamma": 35.0
#   },
#   "augment_args": {
#     "class_name": "training.augment.AdaptiveAugment",
#     "tune_heuristic": "rt",
#     "tune_target": 0.6,
#     "apply_func": "training.augment.augment_pipeline",
#     "apply_args": {
#       "xflip": 1,
#       "rotate90": 1,
#       "xint": 1,
#       "scale": 1,
#       "rotate": 1,
#       "aniso": 1,
#       "xfrac": 1
#     },
#     "tune_kimg": 100
#   },
#   "num_gpus": 1,
#   "image_snapshot_ticks": 4,
#   "network_snapshot_ticks": 4,
#   "train_dataset_args": {
#     "path": "./datasets/tarot_os2",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 512,
#     "mirror_augment": true,
#     "mirror_augment_v": false
#   },
#   "metric_arg_list": [],
#   "metric_dataset_args": {
#     "path": "./datasets/tarot_os2",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 512,
#     "mirror_augment": true,
#     "mirror_augment_v": false
#   },
#   "total_kimg": 25000,
#   "minibatch_size": 8,
#   "minibatch_gpu": 8,
#   "G_smoothing_kimg": 10,
#   "G_smoothing_rampup": null,
#   "resume_pkl": "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00020-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl",
#   "run_dir": "./results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom"
# }
#
# Output directory:  ./results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom
# Training data:     ./datasets/tarot_os2
# Training length:   25000 kimg
# Resolution:        512
# Number of GPUs:    1
#
# Creating output directory...
# Loading training set...
# tcmalloc: large alloc 4294967296 bytes == 0x7e36000 @  0x7f6e1d604001 0x7f6e1a82d765 0x7f6e1a891bb0 0x7f6e1a893a4f 0x7f6e1a92a048 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f6a3bb6a000 @  0x7f6e1d6021e7 0x7f6e1a82d5e1 0x7f6e1a891c78 0x7f6e1a891f37 0x7f6e1a929f28 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f6a3bb6a000 @  0x7f6e1d6021e7 0x7f6e1a82d5e1 0x7f6e1a891c78 0x7f6e1a891f37 0x7f6dd88970c5 0x7f6dd821a902 0x7f6dd821aeb2 0x7f6dd81d3c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Resuming from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00020-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Dense2              262656    (?, 512)            (512, 512)
# G_mapping/Dense3              262656    (?, 512)            (512, 512)
# G_mapping/Dense4              262656    (?, 512)            (512, 512)
# G_mapping/Dense5              262656    (?, 512)            (512, 512)
# G_mapping/Dense6              262656    (?, 512)            (512, 512)
# G_mapping/Dense7              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 16, 512)        -
# dlatent_avg                   -         (512,)              -
# Truncation/Lerp               -         (?, 16, 512)        -
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up    2622465   (?, 512, 64, 64)    (3, 3, 512, 512)
# G_synthesis/64x64/Conv1       2622465   (?, 512, 64, 64)    (3, 3, 512, 512)
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
# G_synthesis/64x64/ToRGB       264195    (?, 3, 64, 64)      (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up  1442561   (?, 256, 128, 128)  (3, 3, 512, 256)
# G_synthesis/128x128/Conv1     721409    (?, 256, 128, 128)  (3, 3, 256, 256)
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
# G_synthesis/128x128/ToRGB     132099    (?, 3, 128, 128)    (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up  426369    (?, 128, 256, 256)  (3, 3, 256, 128)
# G_synthesis/256x256/Conv1     213249    (?, 128, 256, 256)  (3, 3, 128, 128)
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
# G_synthesis/256x256/ToRGB     66051     (?, 3, 256, 256)    (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up  139457    (?, 64, 512, 512)   (3, 3, 128, 64)
# G_synthesis/512x512/Conv1     69761     (?, 64, 512, 512)   (3, 3, 64, 64)
# G_synthesis/512x512/Upsample  -         (?, 3, 512, 512)    -
# G_synthesis/512x512/ToRGB     33027     (?, 3, 512, 512)    (1, 1, 64, 3)
# ---                           ---       ---                 ---
# Total                         30276583
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 512, 512)    -
# labels_in            -         (?, 0)              -
# 512x512/FromRGB      256       (?, 64, 512, 512)   (1, 1, 3, 64)
# 512x512/Conv0        36928     (?, 64, 512, 512)   (3, 3, 64, 64)
# 512x512/Conv1_down   73856     (?, 128, 256, 256)  (3, 3, 64, 128)
# 512x512/Skip         8192      (?, 128, 256, 256)  (1, 1, 64, 128)
# 256x256/Conv0        147584    (?, 128, 256, 256)  (3, 3, 128, 128)
# 256x256/Conv1_down   295168    (?, 256, 128, 128)  (3, 3, 128, 256)
# 256x256/Skip         32768     (?, 256, 128, 128)  (1, 1, 128, 256)
# 128x128/Conv0        590080    (?, 256, 128, 128)  (3, 3, 256, 256)
# 128x128/Conv1_down   1180160   (?, 512, 64, 64)    (3, 3, 256, 512)
# 128x128/Skip         131072    (?, 512, 64, 64)    (1, 1, 256, 512)
# 64x64/Conv0          2359808   (?, 512, 64, 64)    (3, 3, 512, 512)
# 64x64/Conv1_down     2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 64x64/Skip           262144    (?, 512, 32, 32)    (1, 1, 512, 512)
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
# 8x8/Skip             262144    (?, 512, 4, 4)      (1, 1, 512, 512)
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
# Output               513       (?, 1)              (512, 1)
# ---                  ---       ---                 ---
# Total                28982849
#
# Exporting sample images...
# Replicating networks across 1 GPUs...
# Initializing augmentations...
# Setting up optimizers...
# Constructing training graph...
# Finalizing training ops...
# Initializing metrics...
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 1m 38s       sec/tick 19.8    sec/kimg 618.62  maintenance 78.1   gpumem 10.0  augment 0.000
# tick 1     kimg 4.0      time 7m 14s       sec/tick 317.7   sec/kimg 79.43   maintenance 18.0   gpumem 10.0  augment 0.035
# tick 2     kimg 8.0      time 12m 33s      sec/tick 318.9   sec/kimg 79.72   maintenance 0.0    gpumem 10.0  augment 0.072
# tick 3     kimg 12.0     time 17m 52s      sec/tick 319.7   sec/kimg 79.92   maintenance 0.0    gpumem 10.0  augment 0.109
# tick 4     kimg 16.0     time 23m 13s      sec/tick 320.3   sec/kimg 80.07   maintenance 0.0    gpumem 10.0  augment 0.144
# tick 5     kimg 20.0     time 28m 39s      sec/tick 319.9   sec/kimg 79.98   maintenance 6.7    gpumem 10.0  augment 0.182
# tick 6     kimg 24.0     time 34m 00s      sec/tick 320.8   sec/kimg 80.20   maintenance 0.0    gpumem 10.0  augment 0.199
# tick 7     kimg 28.0     time 39m 21s      sec/tick 321.0   sec/kimg 80.26   maintenance 0.0    gpumem 10.0  augment 0.230
# tick 8     kimg 32.0     time 44m 43s      sec/tick 322.2   sec/kimg 80.55   maintenance 0.0    gpumem 10.0  augment 0.267
# tick 9     kimg 36.0     time 50m 10s      sec/tick 322.7   sec/kimg 80.66   maintenance 4.4    gpumem 10.0  augment 0.303
# tick 10    kimg 40.0     time 55m 33s      sec/tick 322.7   sec/kimg 80.67   maintenance 0.0    gpumem 10.0  augment 0.341
# tick 11    kimg 44.0     time 1h 00m 56s   sec/tick 323.5   sec/kimg 80.88   maintenance 0.0    gpumem 10.0  augment 0.375
# tick 12    kimg 48.0     time 1h 06m 21s   sec/tick 324.4   sec/kimg 81.09   maintenance 0.0    gpumem 10.0  augment 0.407
# tick 13    kimg 52.0     time 1h 11m 49s   sec/tick 324.1   sec/kimg 81.02   maintenance 4.2    gpumem 10.0  augment 0.442
# tick 14    kimg 56.0     time 1h 17m 14s   sec/tick 324.7   sec/kimg 81.18   maintenance 0.0    gpumem 10.0  augment 0.474
# tick 15    kimg 60.0     time 1h 22m 39s   sec/tick 324.8   sec/kimg 81.19   maintenance 0.0    gpumem 10.0  augment 0.506
# tick 16    kimg 64.0     time 1h 28m 04s   sec/tick 325.8   sec/kimg 81.45   maintenance 0.0    gpumem 10.0  augment 0.526
# tick 17    kimg 68.0     time 1h 33m 34s   sec/tick 325.5   sec/kimg 81.38   maintenance 4.5    gpumem 10.0  augment 0.542
# tick 18    kimg 72.0     time 1h 39m 00s   sec/tick 325.8   sec/kimg 81.46   maintenance 0.0    gpumem 10.0  augment 0.578
# tick 19    kimg 76.0     time 1h 44m 26s   sec/tick 326.1   sec/kimg 81.54   maintenance 0.0    gpumem 10.0  augment 0.612
# tick 20    kimg 80.0     time 1h 49m 53s   sec/tick 326.5   sec/kimg 81.62   maintenance 0.0    gpumem 10.0  augment 0.647
# tick 21    kimg 84.0     time 1h 55m 25s   sec/tick 326.8   sec/kimg 81.70   maintenance 4.9    gpumem 10.0  augment 0.682
# tick 22    kimg 88.0     time 2h 00m 52s   sec/tick 327.7   sec/kimg 81.93   maintenance 0.0    gpumem 10.0  augment 0.705
# tick 23    kimg 92.0     time 2h 06m 21s   sec/tick 328.2   sec/kimg 82.06   maintenance 0.0    gpumem 10.0  augment 0.737
# tick 24    kimg 96.0     time 2h 11m 49s   sec/tick 328.5   sec/kimg 82.13   maintenance 0.0    gpumem 10.0  augment 0.770
# tick 25    kimg 100.0    time 2h 17m 23s   sec/tick 328.2   sec/kimg 82.04   maintenance 5.4    gpumem 10.0  augment 0.804
# tick 26    kimg 104.0    time 2h 22m 52s   sec/tick 328.9   sec/kimg 82.23   maintenance 0.0    gpumem 10.0  augment 0.833
# tick 27    kimg 108.0    time 2h 28m 21s   sec/tick 329.7   sec/kimg 82.43   maintenance 0.0    gpumem 10.0  augment 0.864
# tick 28    kimg 112.0    time 2h 33m 52s   sec/tick 330.1   sec/kimg 82.53   maintenance 0.0    gpumem 10.0  augment 0.899
# tick 29    kimg 116.0    time 2h 39m 26s   sec/tick 330.1   sec/kimg 82.53   maintenance 4.5    gpumem 10.0  augment 0.932
# tick 30    kimg 120.0    time 2h 44m 57s   sec/tick 330.6   sec/kimg 82.64   maintenance 0.0    gpumem 10.0  augment 0.965
# tick 31    kimg 124.0    time 2h 50m 27s   sec/tick 330.6   sec/kimg 82.66   maintenance 0.0    gpumem 10.0  augment 0.998
# tick 32    kimg 128.0    time 2h 55m 59s   sec/tick 331.4   sec/kimg 82.84   maintenance 0.0    gpumem 10.0  augment 1.030
# tick 33    kimg 132.0    time 3h 01m 34s   sec/tick 330.9   sec/kimg 82.72   maintenance 4.4    gpumem 10.0  augment 1.062
# tick 34    kimg 136.0    time 3h 07m 04s   sec/tick 330.1   sec/kimg 82.52   maintenance 0.0    gpumem 10.0  augment 1.074
# tick 35    kimg 140.0    time 3h 12m 34s   sec/tick 330.1   sec/kimg 82.53   maintenance 0.0    gpumem 10.0  augment 1.107
# tick 36    kimg 144.0    time 3h 18m 05s   sec/tick 330.3   sec/kimg 82.59   maintenance 0.0    gpumem 10.0  augment 1.141
# tick 37    kimg 148.0    time 3h 23m 39s   sec/tick 330.2   sec/kimg 82.55   maintenance 4.4    gpumem 10.0  augment 1.174
# tick 38    kimg 152.0    time 3h 29m 10s   sec/tick 330.6   sec/kimg 82.65   maintenance 0.0    gpumem 10.0  augment 1.208
# tick 39    kimg 156.0    time 3h 34m 41s   sec/tick 330.9   sec/kimg 82.73   maintenance 0.0    gpumem 10.0  augment 1.240
# tick 40    kimg 160.0    time 3h 40m 12s   sec/tick 331.2   sec/kimg 82.79   maintenance 0.0    gpumem 10.0  augment 1.270
# tick 41    kimg 164.0    time 3h 45m 48s   sec/tick 331.5   sec/kimg 82.87   maintenance 4.4    gpumem 10.0  augment 1.303
# tick 42    kimg 168.0    time 3h 51m 20s   sec/tick 332.2   sec/kimg 83.06   maintenance 0.0    gpumem 10.0  augment 1.335
# tick 43    kimg 172.0    time 3h 56m 51s   sec/tick 331.2   sec/kimg 82.79   maintenance 0.0    gpumem 10.0  augment 1.367
# tick 44    kimg 176.0    time 4h 02m 23s   sec/tick 331.6   sec/kimg 82.89   maintenance 0.0    gpumem 10.0  augment 1.403
# tick 45    kimg 180.0    time 4h 07m 59s   sec/tick 332.0   sec/kimg 83.00   maintenance 4.6    gpumem 10.0  augment 1.435
# tick 46    kimg 184.0    time 4h 13m 31s   sec/tick 332.0   sec/kimg 83.00   maintenance 0.0    gpumem 10.0  augment 1.470
# tick 47    kimg 188.0    time 4h 19m 03s   sec/tick 331.7   sec/kimg 82.92   maintenance 0.0    gpumem 10.0  augment 1.504
# tick 48    kimg 192.0    time 4h 24m 35s   sec/tick 332.3   sec/kimg 83.08   maintenance 0.0    gpumem 10.0  augment 1.540
# tick 49    kimg 196.0    time 4h 30m 12s   sec/tick 332.1   sec/kimg 83.03   maintenance 4.5    gpumem 10.0  augment 1.572
# tick 50    kimg 200.0    time 4h 35m 44s   sec/tick 332.3   sec/kimg 83.06   maintenance 0.0    gpumem 10.0  augment 1.605
# tick 51    kimg 204.0    time 4h 41m 17s   sec/tick 332.2   sec/kimg 83.05   maintenance 0.0    gpumem 10.0  augment 1.636
# tick 52    kimg 208.0    time 4h 46m 49s   sec/tick 332.5   sec/kimg 83.13   maintenance 0.0    gpumem 10.0  augment 1.668
# tick 53    kimg 212.0    time 4h 52m 26s   sec/tick 332.4   sec/kimg 83.11   maintenance 4.6    gpumem 10.0  augment 1.697
# tick 54    kimg 216.0    time 4h 57m 58s   sec/tick 331.6   sec/kimg 82.90   maintenance 0.0    gpumem 10.0  augment 1.724
# tick 55    kimg 220.0    time 5h 03m 29s   sec/tick 331.4   sec/kimg 82.86   maintenance 0.0    gpumem 10.0  augment 1.754
# tick 56    kimg 224.0    time 5h 09m 01s   sec/tick 332.0   sec/kimg 83.00   maintenance 0.0    gpumem 10.0  augment 1.785
# tick 57    kimg 228.0    time 5h 14m 37s   sec/tick 330.9   sec/kimg 82.72   maintenance 4.8    gpumem 10.0  augment 1.817
# tick 58    kimg 232.0    time 5h 20m 08s   sec/tick 331.4   sec/kimg 82.86   maintenance 0.0    gpumem 10.0  augment 1.852
# tick 59    kimg 236.0    time 5h 25m 40s   sec/tick 332.0   sec/kimg 83.01   maintenance 0.0    gpumem 10.0  augment 1.883
# tick 60    kimg 240.0    time 5h 31m 12s   sec/tick 331.5   sec/kimg 82.86   maintenance 0.0    gpumem 10.0  augment 1.916
# tick 61    kimg 244.0    time 5h 36m 47s   sec/tick 330.4   sec/kimg 82.59   maintenance 4.4    gpumem 10.0  augment 1.947
# tick 62    kimg 248.0    time 5h 42m 17s   sec/tick 330.8   sec/kimg 82.71   maintenance 0.0    gpumem 10.0  augment 1.980
# tick 63    kimg 252.0    time 5h 47m 48s   sec/tick 330.7   sec/kimg 82.68   maintenance 0.0    gpumem 10.0  augment 2.017
# tick 64    kimg 256.0    time 5h 53m 19s   sec/tick 330.4   sec/kimg 82.60   maintenance 0.0    gpumem 10.0  augment 2.049
# tick 65    kimg 260.0    time 5h 58m 54s   sec/tick 331.0   sec/kimg 82.74   maintenance 4.4    gpumem 10.0  augment 2.078
# tick 66    kimg 264.0    time 6h 04m 25s   sec/tick 330.8   sec/kimg 82.71   maintenance 0.0    gpumem 10.0  augment 2.112
# tick 67    kimg 268.0    time 6h 09m 55s   sec/tick 330.5   sec/kimg 82.63   maintenance 0.0    gpumem 10.0  augment 2.146
# tick 68    kimg 272.0    time 6h 15m 27s   sec/tick 331.6   sec/kimg 82.89   maintenance 0.0    gpumem 10.0  augment 2.175
# tick 69    kimg 276.0    time 6h 21m 03s   sec/tick 331.3   sec/kimg 82.82   maintenance 4.4    gpumem 10.0  augment 2.209
# tick 70    kimg 280.0    time 6h 26m 34s   sec/tick 331.3   sec/kimg 82.83   maintenance 0.0    gpumem 10.0  augment 2.243
# tick 71    kimg 284.0    time 6h 32m 05s   sec/tick 330.9   sec/kimg 82.72   maintenance 0.0    gpumem 10.0  augment 2.273
# tick 72    kimg 288.0    time 6h 37m 36s   sec/tick 331.4   sec/kimg 82.85   maintenance 0.0    gpumem 10.0  augment 2.306
# tick 73    kimg 292.0    time 6h 43m 12s   sec/tick 331.3   sec/kimg 82.81   maintenance 4.3    gpumem 10.0  augment 2.339
# tick 74    kimg 296.0    time 6h 48m 42s   sec/tick 330.4   sec/kimg 82.59   maintenance 0.0    gpumem 10.0  augment 2.357
# tick 75    kimg 300.0    time 6h 54m 14s   sec/tick 331.6   sec/kimg 82.89   maintenance 0.0    gpumem 10.0  augment 2.388
# tick 76    kimg 304.0    time 6h 59m 46s   sec/tick 332.5   sec/kimg 83.13   maintenance 0.0    gpumem 10.0  augment 2.420
# tick 77    kimg 308.0    time 7h 05m 23s   sec/tick 332.2   sec/kimg 83.05   maintenance 4.9    gpumem 10.0  augment 2.438
# tick 78    kimg 312.0    time 7h 10m 55s   sec/tick 332.1   sec/kimg 83.01   maintenance 0.0    gpumem 10.0  augment 2.473
# tick 79    kimg 316.0    time 7h 16m 28s   sec/tick 332.3   sec/kimg 83.07   maintenance 0.0    gpumem 10.0  augment 2.504
# tick 80    kimg 320.0    time 7h 22m 00s   sec/tick 332.3   sec/kimg 83.07   maintenance 0.0    gpumem 10.0  augment 2.533
# tick 81    kimg 324.0    time 7h 27m 35s   sec/tick 330.5   sec/kimg 82.63   maintenance 4.6    gpumem 10.0  augment 2.564
# tick 82    kimg 328.0    time 7h 33m 06s   sec/tick 331.1   sec/kimg 82.78   maintenance 0.0    gpumem 10.0  augment 2.598
# tick 83    kimg 332.0    time 7h 38m 38s   sec/tick 331.3   sec/kimg 82.82   maintenance 0.0    gpumem 10.0  augment 2.634
# tick 84    kimg 336.0    time 7h 44m 09s   sec/tick 331.5   sec/kimg 82.88   maintenance 0.0    gpumem 10.0  augment 2.669
# tick 85    kimg 340.0    time 7h 49m 45s   sec/tick 330.7   sec/kimg 82.67   maintenance 5.2    gpumem 10.0  augment 2.702
# tick 86    kimg 344.0    time 7h 55m 16s   sec/tick 331.3   sec/kimg 82.82   maintenance 0.0    gpumem 10.0  augment 2.734
# tick 87    kimg 348.0    time 8h 00m 47s   sec/tick 331.1   sec/kimg 82.78   maintenance 0.0    gpumem 10.0  augment 2.757
# tick 88    kimg 352.0    time 8h 06m 18s   sec/tick 330.9   sec/kimg 82.71   maintenance 0.0    gpumem 10.0  augment 2.793
# tick 89    kimg 356.0    time 8h 11m 53s   sec/tick 330.4   sec/kimg 82.60   maintenance 4.4    gpumem 10.0  augment 2.788
# tick 90    kimg 360.0    time 8h 17m 24s   sec/tick 331.0   sec/kimg 82.75   maintenance 0.0    gpumem 10.0  augment 2.821
# tick 91    kimg 364.0    time 8h 22m 55s   sec/tick 330.9   sec/kimg 82.72   maintenance 0.0    gpumem 10.0  augment 2.855
# tick 92    kimg 368.0    time 8h 28m 26s   sec/tick 331.0   sec/kimg 82.76   maintenance 0.0    gpumem 10.0  augment 2.888
# tick 93    kimg 372.0    time 8h 34m 02s   sec/tick 331.3   sec/kimg 82.83   maintenance 4.4    gpumem 10.0  augment 2.921
# tick 94    kimg 376.0    time 8h 39m 33s   sec/tick 331.6   sec/kimg 82.90   maintenance 0.0    gpumem 10.0  augment 2.955
# tick 95    kimg 380.0    time 8h 45m 04s   sec/tick 330.6   sec/kimg 82.64   maintenance 0.0    gpumem 10.0  augment 2.989
# tick 96    kimg 384.0    time 8h 50m 35s   sec/tick 331.0   sec/kimg 82.76   maintenance 0.0    gpumem 10.0  augment 3.021
# tick 97    kimg 388.0    time 8h 56m 12s   sec/tick 331.6   sec/kimg 82.90   maintenance 5.2    gpumem 10.0  augment 3.057
# tick 98    kimg 392.0    time 9h 01m 42s   sec/tick 330.6   sec/kimg 82.65   maintenance 0.0    gpumem 10.0  augment 3.083
# tick 99    kimg 396.0    time 9h 07m 13s   sec/tick 330.9   sec/kimg 82.73   maintenance 0.0    gpumem 10.0  augment 3.111
# tick 100   kimg 400.0    time 9h 12m 45s   sec/tick 332.0   sec/kimg 82.99   maintenance 0.0    gpumem 10.0  augment 3.143
# tick 101   kimg 404.0    time 9h 18m 21s   sec/tick 331.2   sec/kimg 82.80   maintenance 5.0    gpumem 10.0  augment 3.176
# tick 102   kimg 408.0    time 9h 23m 52s   sec/tick 330.3   sec/kimg 82.58   maintenance 0.0    gpumem 10.0  augment 3.207
# tick 103   kimg 412.0    time 9h 29m 23s   sec/tick 331.2   sec/kimg 82.80   maintenance 0.0    gpumem 10.0  augment 3.242
# tick 104   kimg 416.0    time 9h 34m 54s   sec/tick 331.1   sec/kimg 82.78   maintenance 0.0    gpumem 10.0  augment 3.276
# tick 105   kimg 420.0    time 9h 40m 29s   sec/tick 330.6   sec/kimg 82.65   maintenance 4.5    gpumem 10.0  augment 3.311
# tick 106   kimg 424.0    time 9h 46m 01s   sec/tick 331.4   sec/kimg 82.85   maintenance 0.0    gpumem 10.0  augment 3.345
# tick 107   kimg 428.0    time 9h 51m 31s   sec/tick 330.7   sec/kimg 82.68   maintenance 0.0    gpumem 10.0  augment 3.376
# tick 108   kimg 432.0    time 9h 57m 03s   sec/tick 331.2   sec/kimg 82.81   maintenance 0.0    gpumem 10.0  augment 3.406
# tick 109   kimg 436.0    time 10h 02m 38s  sec/tick 331.0   sec/kimg 82.75   maintenance 4.5    gpumem 10.0  augment 3.439
# tick 110   kimg 440.0    time 10h 08m 10s  sec/tick 331.6   sec/kimg 82.91   maintenance 0.0    gpumem 10.0  augment 3.474
# tick 111   kimg 444.0    time 10h 13m 42s  sec/tick 332.0   sec/kimg 83.00   maintenance 0.0    gpumem 10.0  augment 3.502
# tick 112   kimg 448.0    time 10h 19m 13s  sec/tick 331.1   sec/kimg 82.77   maintenance 0.0    gpumem 10.0  augment 3.536
# tick 113   kimg 452.0    time 10h 24m 49s  sec/tick 331.3   sec/kimg 82.84   maintenance 4.6    gpumem 10.0  augment 3.567
# tick 114   kimg 456.0    time 10h 30m 20s  sec/tick 331.7   sec/kimg 82.92   maintenance 0.0    gpumem 10.0  augment 3.600
# tick 115   kimg 460.0    time 10h 35m 51s  sec/tick 330.8   sec/kimg 82.69   maintenance 0.0    gpumem 10.0  augment 3.634
# tick 116   kimg 464.0    time 10h 41m 22s  sec/tick 331.0   sec/kimg 82.75   maintenance 0.0    gpumem 10.0  augment 3.665
# tick 117   kimg 468.0    time 10h 46m 57s  sec/tick 330.8   sec/kimg 82.70   maintenance 4.6    gpumem 10.0  augment 3.683
# tick 118   kimg 472.0    time 10h 52m 28s  sec/tick 330.7   sec/kimg 82.67   maintenance 0.0    gpumem 10.0  augment 3.716
# tick 119   kimg 476.0    time 10h 57m 59s  sec/tick 330.7   sec/kimg 82.68   maintenance 0.0    gpumem 10.0  augment 3.750
# tick 120   kimg 480.0    time 11h 03m 31s  sec/tick 331.7   sec/kimg 82.93   maintenance 0.0    gpumem 10.0  augment 3.784
# tick 121   kimg 484.0    time 11h 09m 07s  sec/tick 331.6   sec/kimg 82.90   maintenance 4.5    gpumem 10.0  augment 3.802
# tick 122   kimg 488.0    time 11h 14m 38s  sec/tick 331.2   sec/kimg 82.79   maintenance 0.0    gpumem 10.0  augment 3.836
# tick 123   kimg 492.0    time 11h 20m 10s  sec/tick 331.8   sec/kimg 82.96   maintenance 0.0    gpumem 10.0  augment 3.868
# tick 124   kimg 496.0    time 11h 25m 42s  sec/tick 331.8   sec/kimg 82.95   maintenance 0.0    gpumem 10.0  augment 3.901
# tick 125   kimg 500.0    time 11h 31m 17s  sec/tick 331.0   sec/kimg 82.75   maintenance 4.5    gpumem 10.0  augment 3.935
# tick 126   kimg 504.0    time 11h 36m 48s  sec/tick 331.0   sec/kimg 82.75   maintenance 0.0    gpumem 10.0  augment 3.969
# tick 127   kimg 508.0    time 11h 42m 20s  sec/tick 331.7   sec/kimg 82.93   maintenance 0.0    gpumem 10.0  augment 3.999
# tick 128   kimg 512.0    time 11h 47m 52s  sec/tick 331.7   sec/kimg 82.93   maintenance 0.0    gpumem 10.0  augment 4.027
# tick 129   kimg 516.0    time 11h 53m 28s  sec/tick 331.3   sec/kimg 82.82   maintenance 5.2    gpumem 10.0  augment 4.060
# tick 130   kimg 520.0    time 11h 59m 00s  sec/tick 331.9   sec/kimg 82.97   maintenance 0.0    gpumem 10.0  augment 4.091
# tick 131   kimg 524.0    time 12h 04m 31s  sec/tick 331.4   sec/kimg 82.85   maintenance 0.0    gpumem 10.0  augment 4.124
# tick 132   kimg 528.0    time 12h 10m 04s  sec/tick 332.2   sec/kimg 83.04   maintenance 0.0    gpumem 10.0  augment 4.153
# tick 133   kimg 532.0    time 12h 15m 39s  sec/tick 331.0   sec/kimg 82.76   maintenance 4.9    gpumem 10.0  augment 4.188
# tick 134   kimg 536.0    time 12h 21m 11s  sec/tick 331.4   sec/kimg 82.84   maintenance 0.0    gpumem 10.0  augment 4.222
# tick 135   kimg 540.0    time 12h 26m 43s  sec/tick 331.7   sec/kimg 82.93   maintenance 0.0    gpumem 10.0  augment 4.257
# tick 136   kimg 544.0    time 12h 32m 14s  sec/tick 331.2   sec/kimg 82.79   maintenance 0.0    gpumem 10.0  augment 4.288
# tick 137   kimg 548.0    time 12h 37m 50s  sec/tick 331.6   sec/kimg 82.89   maintenance 4.4    gpumem 10.0  augment 4.320
# tick 138   kimg 552.0    time 12h 43m 22s  sec/tick 331.8   sec/kimg 82.95   maintenance 0.0    gpumem 10.0  augment 4.348
# tick 139   kimg 556.0    time 12h 48m 53s  sec/tick 331.4   sec/kimg 82.86   maintenance 0.0    gpumem 10.0  augment 4.379
# tick 140   kimg 560.0    time 12h 54m 25s  sec/tick 331.8   sec/kimg 82.94   maintenance 0.0    gpumem 10.0  augment 4.411
# tick 141   kimg 564.0    time 13h 00m 01s  sec/tick 332.0   sec/kimg 83.00   maintenance 4.4    gpumem 10.0  augment 4.444
# tick 142   kimg 568.0    time 13h 05m 33s  sec/tick 331.9   sec/kimg 82.98   maintenance 0.0    gpumem 10.0  augment 4.474
# tick 143   kimg 572.0    time 13h 11m 05s  sec/tick 331.7   sec/kimg 82.91   maintenance 0.0    gpumem 10.0  augment 4.508
# tick 144   kimg 576.0    time 13h 16m 35s  sec/tick 330.6   sec/kimg 82.64   maintenance 0.0    gpumem 10.0  augment 4.540
# tick 145   kimg 580.0    time 13h 22m 10s  sec/tick 329.7   sec/kimg 82.42   maintenance 5.1    gpumem 10.0  augment 4.568
# tick 146   kimg 584.0    time 13h 27m 40s  sec/tick 329.9   sec/kimg 82.48   maintenance 0.0    gpumem 10.0  augment 4.605
# tick 147   kimg 588.0    time 13h 33m 10s  sec/tick 330.2   sec/kimg 82.56   maintenance 0.0    gpumem 10.0  augment 4.637
# tick 148   kimg 592.0    time 13h 38m 41s  sec/tick 330.4   sec/kimg 82.61   maintenance 0.0    gpumem 10.0  augment 4.670
# tick 149   kimg 596.0    time 13h 44m 16s  sec/tick 330.5   sec/kimg 82.61   maintenance 4.6    gpumem 10.0  augment 4.703
# tick 150   kimg 600.0    time 13h 49m 46s  sec/tick 330.4   sec/kimg 82.61   maintenance 0.0    gpumem 10.0  augment 4.736
# tick 151   kimg 604.0    time 13h 55m 17s  sec/tick 330.7   sec/kimg 82.67   maintenance 0.0    gpumem 10.0  augment 4.753
# tick 152   kimg 608.0    time 14h 00m 48s  sec/tick 331.1   sec/kimg 82.79   maintenance 0.0    gpumem 10.0  augment 4.786
# tick 153   kimg 612.0    time 14h 06m 23s  sec/tick 330.1   sec/kimg 82.52   maintenance 4.4    gpumem 10.0  augment 4.801
# tick 154   kimg 616.0    time 14h 11m 53s  sec/tick 330.1   sec/kimg 82.53   maintenance 0.0    gpumem 10.0  augment 4.830
# tick 155   kimg 620.0    time 14h 17m 23s  sec/tick 329.9   sec/kimg 82.48   maintenance 0.0    gpumem 10.0  augment 4.864
# tick 156   kimg 624.0    time 14h 22m 53s  sec/tick 330.1   sec/kimg 82.52   maintenance 0.0    gpumem 10.0  augment 4.899
# tick 157   kimg 628.0    time 14h 28m 27s  sec/tick 329.6   sec/kimg 82.39   maintenance 4.3    gpumem 10.0  augment 4.930
# tick 158   kimg 632.0    time 14h 33m 56s  sec/tick 329.6   sec/kimg 82.41   maintenance 0.0    gpumem 10.0  augment 4.962
# tick 159   kimg 636.0    time 14h 39m 27s  sec/tick 330.9   sec/kimg 82.74   maintenance 0.0    gpumem 10.0  augment 4.994
# tick 160   kimg 640.0    time 14h 44m 58s  sec/tick 331.0   sec/kimg 82.76   maintenance 0.0    gpumem 10.0  augment 5.028
# tick 161   kimg 644.0    time 14h 50m 34s  sec/tick 331.1   sec/kimg 82.77   maintenance 4.5    gpumem 10.0  augment 5.058
# tick 162   kimg 648.0    time 14h 56m 05s  sec/tick 331.3   sec/kimg 82.83   maintenance 0.0    gpumem 10.0  augment 5.090
# tick 163   kimg 652.0    time 15h 01m 36s  sec/tick 331.0   sec/kimg 82.76   maintenance 0.0    gpumem 10.0  augment 5.123
# tick 164   kimg 656.0    time 15h 07m 08s  sec/tick 331.5   sec/kimg 82.87   maintenance 0.0    gpumem 10.0  augment 5.152
# tick 165   kimg 660.0    time 15h 12m 43s  sec/tick 330.8   sec/kimg 82.71   maintenance 4.5    gpumem 10.0  augment 5.180
# tick 166   kimg 664.0    time 15h 18m 14s  sec/tick 330.7   sec/kimg 82.68   maintenance 0.0    gpumem 10.0  augment 5.214
# tick 167   kimg 668.0    time 15h 23m 45s  sec/tick 331.0   sec/kimg 82.74   maintenance 0.0    gpumem 10.0  augment 5.246
# tick 168   kimg 672.0    time 15h 29m 17s  sec/tick 331.9   sec/kimg 82.97   maintenance 0.0    gpumem 10.0  augment 5.280
# tick 169   kimg 676.0    time 15h 34m 53s  sec/tick 331.8   sec/kimg 82.95   maintenance 4.4    gpumem 10.0  augment 5.313
# tick 170   kimg 680.0    time 15h 40m 25s  sec/tick 331.9   sec/kimg 82.97   maintenance 0.0    gpumem 10.0  augment 5.348
# tick 171   kimg 684.0    time 15h 45m 57s  sec/tick 332.0   sec/kimg 82.99   maintenance 0.0    gpumem 10.0  augment 5.375
# tick 172   kimg 688.0    time 15h 51m 28s  sec/tick 331.2   sec/kimg 82.81   maintenance 0.0    gpumem 10.0  augment 5.404
# tick 173   kimg 692.0    time 15h 57m 04s  sec/tick 331.7   sec/kimg 82.92   maintenance 4.5    gpumem 10.0  augment 5.437
# tick 174   kimg 696.0    time 16h 02m 36s  sec/tick 332.1   sec/kimg 83.03   maintenance 0.0    gpumem 10.0  augment 5.471
# tick 175   kimg 700.0    time 16h 08m 08s  sec/tick 331.9   sec/kimg 82.99   maintenance 0.0    gpumem 10.0  augment 5.500
# tick 176   kimg 704.0    time 16h 13m 41s  sec/tick 332.4   sec/kimg 83.10   maintenance 0.0    gpumem 10.0  augment 5.534
# tick 177   kimg 708.0    time 16h 19m 17s  sec/tick 331.9   sec/kimg 82.97   maintenance 4.5    gpumem 10.0  augment 5.566
# tick 178   kimg 712.0    time 16h 24m 49s  sec/tick 332.2   sec/kimg 83.05   maintenance 0.0    gpumem 10.0  augment 5.598
# tick 179   kimg 716.0    time 16h 30m 21s  sec/tick 331.7   sec/kimg 82.93   maintenance 0.0    gpumem 10.0  augment 5.631
# tick 180   kimg 720.0    time 16h 35m 53s  sec/tick 332.0   sec/kimg 83.01   maintenance 0.0    gpumem 10.0  augment 5.662
# tick 181   kimg 724.0    time 16h 41m 29s  sec/tick 331.8   sec/kimg 82.96   maintenance 4.5    gpumem 10.0  augment 5.694
# tick 182   kimg 728.0    time 16h 47m 01s  sec/tick 331.6   sec/kimg 82.91   maintenance 0.0    gpumem 10.0  augment 5.708
# tick 183   kimg 732.0    time 16h 52m 33s  sec/tick 331.6   sec/kimg 82.89   maintenance 0.0    gpumem 10.0  augment 5.738
# tick 184   kimg 736.0    time 16h 58m 04s  sec/tick 331.8   sec/kimg 82.96   maintenance 0.0    gpumem 10.0  augment 5.771
# tick 185   kimg 740.0    time 17h 03m 40s  sec/tick 331.3   sec/kimg 82.83   maintenance 4.5    gpumem 10.0  augment 5.799
# tick 186   kimg 744.0    time 17h 09m 12s  sec/tick 331.5   sec/kimg 82.86   maintenance 0.0    gpumem 10.0  augment 5.831
# tick 187   kimg 748.0    time 17h 14m 43s  sec/tick 331.5   sec/kimg 82.87   maintenance 0.0    gpumem 10.0  augment 5.860
# tick 188   kimg 752.0    time 17h 20m 14s  sec/tick 331.1   sec/kimg 82.78   maintenance 0.0    gpumem 10.0  augment 5.870
# tick 189   kimg 756.0    time 17h 25m 51s  sec/tick 331.5   sec/kimg 82.88   maintenance 4.8    gpumem 10.0  augment 5.871
# tick 190   kimg 760.0    time 17h 31m 23s  sec/tick 332.3   sec/kimg 83.07   maintenance 0.0    gpumem 10.0  augment 5.904
# tick 191   kimg 764.0    time 17h 36m 55s  sec/tick 332.3   sec/kimg 83.08   maintenance 0.0    gpumem 10.0  augment 5.939
# tick 192   kimg 768.0    time 17h 42m 28s  sec/tick 332.8   sec/kimg 83.21   maintenance 0.0    gpumem 10.0  augment 5.971
# tick 193   kimg 772.0    time 17h 48m 05s  sec/tick 332.9   sec/kimg 83.21   maintenance 4.4    gpumem 10.0  augment 6.004
# tick 194   kimg 776.0    time 17h 53m 38s  sec/tick 332.5   sec/kimg 83.13   maintenance 0.0    gpumem 10.0  augment 6.035
# tick 195   kimg 780.0    time 17h 59m 11s  sec/tick 332.5   sec/kimg 83.14   maintenance 0.0    gpumem 10.0  augment 6.067
# tick 196   kimg 784.0    time 18h 04m 43s  sec/tick 332.8   sec/kimg 83.19   maintenance 0.0    gpumem 10.0  augment 6.097
# tick 197   kimg 788.0    time 18h 10m 20s  sec/tick 332.1   sec/kimg 83.03   maintenance 4.7    gpumem 10.0  augment 6.131
# tick 198   kimg 792.0    time 18h 15m 52s  sec/tick 332.3   sec/kimg 83.06   maintenance 0.0    gpumem 10.0  augment 6.158
# tick 199   kimg 796.0    time 18h 21m 25s  sec/tick 332.5   sec/kimg 83.12   maintenance 0.0    gpumem 10.0  augment 6.190
# tick 200   kimg 800.0    time 18h 26m 57s  sec/tick 332.2   sec/kimg 83.04   maintenance 0.0    gpumem 10.0  augment 6.222
# tick 201   kimg 804.0    time 18h 32m 33s  sec/tick 331.4   sec/kimg 82.85   maintenance 4.6    gpumem 10.0  augment 6.259
# tick 202   kimg 808.0    time 18h 38m 03s  sec/tick 330.3   sec/kimg 82.57   maintenance 0.0    gpumem 10.0  augment 6.289
# tick 203   kimg 812.0    time 18h 43m 33s  sec/tick 329.6   sec/kimg 82.39   maintenance 0.0    gpumem 10.0  augment 6.311
# tick 204   kimg 816.0    time 18h 49m 03s  sec/tick 329.6   sec/kimg 82.39   maintenance 0.0    gpumem 10.0  augment 6.342
# tick 205   kimg 820.0    time 18h 54m 36s  sec/tick 329.5   sec/kimg 82.38   maintenance 4.2    gpumem 10.0  augment 6.374
# tick 206   kimg 824.0    time 19h 00m 05s  sec/tick 329.1   sec/kimg 82.27   maintenance 0.0    gpumem 10.0  augment 6.404
# tick 207   kimg 828.0    time 19h 05m 35s  sec/tick 329.4   sec/kimg 82.34   maintenance 0.0    gpumem 10.0  augment 6.404
# tick 208   kimg 832.0    time 19h 11m 04s  sec/tick 329.4   sec/kimg 82.35   maintenance 0.0    gpumem 10.0  augment 6.437
# tick 209   kimg 836.0    time 19h 16m 38s  sec/tick 329.2   sec/kimg 82.29   maintenance 4.3    gpumem 10.0  augment 6.467
# tick 210   kimg 840.0    time 19h 22m 07s  sec/tick 329.2   sec/kimg 82.30   maintenance 0.0    gpumem 10.0  augment 6.499

# %% [markdown]
# I frequently ran into mode collapse issues while training with some of the standard hyperparameters. I found the best training arguments for this project were:
# * Learning Rate: 0.001 - 0.0016
# * Increase batch size from 4 to 8
# * Increase gamma from 10 to 30-35

# %% [markdown]
# ### While it’s training...
# **Once the above cell is running you should be training!**
#
# Don’t close this tab! Colab needs to be open and running in order to continue training. Every ~15min or so a new line should get added to your output, indicated its still training. Depending on you `snapshot_count` setting you should see the results folder in your Google drive folder fill with both samples (`fakesXXXXXx.jpg`) and model weights (`network-snapshot-XXXXXX.pkl`). The samples are worth looking at while it trains but don’t get too worried about each individual sample.
#
# If you chose a metric, you will also see scores for each snapshot. Don’t obsess over these! they are a guide, it can go up or down slightly for each snapshot. What you want to see is a gradual lowering of the score over time.
#
# Once Colab shuts off, you can Reconnect the notebook and re-run every cell from top to bottom. Make sure you update the `resume_from` path to continue training from the latest model.

# %% [markdown]
# ## Generating Images

# %% [markdown]
# As I mentioned, Derrick Schultz has put out a *ton* of great content on working with GANs on his [YouTube channel](https://www.youtube.com/channel/UCaZuPdmZ380SFUMKHVsv_AA). I studied [this video](https://www.youtube.com/watch?v=h0zwLMIt-hI&amp;t=1s) to play around with the following image generation options.

# %%
# !pip install opensimplex
# Out:
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/9c/ad/9b758f9ff9dcd23fc574bb3aa1de844adb1179c9be9711e9f798614d4b2f/opensimplex-0.3-py3-none-any.whl
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.3

# %%
pkl_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"

out_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/images-final"


# !python generate.py generate-images --network={pkl_path} --seeds=161 --outdir={out_path}
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 161 (0/1) ...

# %% [markdown]
# Note: I probably reviewed a thousand images to pick my final 22 for the tarot deck.

# %% [markdown]
# ### Truncation
#
# * Morph images from less realistic to more realistic
# * less truncated = less realisitc
# * can be a float
# * reduces latent space

# %%
pkl_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"


# !python generate.py truncation-traversal --network={pkl_path} --seed=161 --start=-2.0 --stop=2.0 --increment=0.05 --outdir='./tt' --fps=30
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating truncation -2.00
# Generating truncation -1.95
# Generating truncation -1.90
# Generating truncation -1.85
# Generating truncation -1.80
# Generating truncation -1.75
# Generating truncation -1.70
# Generating truncation -1.65
# Generating truncation -1.60
# Generating truncation -1.55
# Generating truncation -1.50
# Generating truncation -1.45
# Generating truncation -1.40
# Generating truncation -1.35
# Generating truncation -1.30
# Generating truncation -1.25
# Generating truncation -1.20
# Generating truncation -1.15
# Generating truncation -1.10
# Generating truncation -1.05
# Generating truncation -1.00
# Generating truncation -0.95
# Generating truncation -0.90
# Generating truncation -0.85
# Generating truncation -0.80
# Generating truncation -0.75
# Generating truncation -0.70
# Generating truncation -0.65
# Generating truncation -0.60
# Generating truncation -0.55
# Generating truncation -0.50
# Generating truncation -0.45
# Generating truncation -0.40
# Generating truncation -0.35
# Generating truncation -0.30
# Generating truncation -0.25
# Generating truncation -0.20
# Generating truncation -0.15
# Generating truncation -0.10
# Generating truncation -0.05
# Generating truncation 0.00
# Generating truncation 0.05
# Generating truncation 0.10
# Generating truncation 0.15
# Generating truncation 0.20
# Generating truncation 0.25
# Generating truncation 0.30
# Generating truncation 0.35
# Generating truncation 0.40
# Generating truncation 0.45
# Generating truncation 0.50
# Generating truncation 0.55
# Generating truncation 0.60
# Generating truncation 0.65
# Generating truncation 0.70
# Generating truncation 0.75
# Generating truncation 0.80
# Generating truncation 0.85
# Generating truncation 0.90
# Generating truncation 0.95
# Generating truncation 1.00
# Generating truncation 1.05
# Generating truncation 1.10
# Generating truncation 1.15
# Generating truncation 1.20
# Generating truncation 1.25
# Generating truncation 1.30
# Generating truncation 1.35
# Generating truncation 1.40
# Generating truncation 1.45
# Generating truncation 1.50
# Generating truncation 1.55
# Generating truncation 1.60
# Generating truncation 1.65
# Generating truncation 1.70
# Generating truncation 1.75
# Generating truncation 1.80
# Generating truncation 1.85
# Generating truncation 1.90
# Generating truncation 1.95
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './tt/frame%05d.png':
#   Duration: 00:00:03.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5603c7b5be00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5603c7b5be00] profile High, level 3.0
# [libx264 @ 0x5603c7b5be00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './tt/truncation-traversal-seed161-start-2.0-stop2.0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 61 q=-1.0 Lsize=    1192kB time=00:00:02.56 bitrate=3803.8kbits/s speed=1.96x
# video:1190kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.137767%
# [libx264 @ 0x5603c7b5be00] frame I:2     Avg QP:25.31  size: 26782
# [libx264 @ 0x5603c7b5be00] frame P:35    Avg QP:29.38  size: 18276
# [libx264 @ 0x5603c7b5be00] frame B:43    Avg QP:32.13  size: 12205
# [libx264 @ 0x5603c7b5be00] consecutive B-frames: 27.5%  2.5%  0.0% 70.0%
# [libx264 @ 0x5603c7b5be00] mb I  I16..4: 11.5% 51.7% 36.8%
# [libx264 @ 0x5603c7b5be00] mb P  I16..4:  2.6%  9.7% 11.6%  P16..4: 18.4% 13.8% 11.2%  0.0%  0.0%    skip:32.9%
# [libx264 @ 0x5603c7b5be00] mb B  I16..4:  0.6%  1.7%  4.9%  B16..8: 17.0% 11.6%  7.6%  direct: 9.0%  skip:47.6%  L0:32.6% L1:33.6% BI:33.8%
# [libx264 @ 0x5603c7b5be00] 8x8 transform intra:38.4% inter:37.4%
# [libx264 @ 0x5603c7b5be00] coded y,uvDC,uvAC intra: 72.1% 70.4% 52.9% inter: 30.4% 22.8% 5.9%
# [libx264 @ 0x5603c7b5be00] i16 v,h,dc,p: 70% 17%  5%  8%
# [libx264 @ 0x5603c7b5be00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31%  8% 32%  5%  3%  6%  4%  5%  4%
# [libx264 @ 0x5603c7b5be00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 14% 14%  8%  6%  9%  7%  7%  6%
# [libx264 @ 0x5603c7b5be00] i8c dc,h,v,p: 46% 16% 30%  8%
# [libx264 @ 0x5603c7b5be00] Weighted P-Frames: Y:8.6% UV:2.9%
# [libx264 @ 0x5603c7b5be00] ref P L0: 76.7% 13.9%  6.9%  2.5%  0.1%
# [libx264 @ 0x5603c7b5be00] ref B L0: 94.1%  4.3%  1.5%
# [libx264 @ 0x5603c7b5be00] ref B L1: 98.8%  1.2%
# [libx264 @ 0x5603c7b5be00] kb/s:3654.10

# %% [markdown]
# ### Interpolation
#
# * Move between different points in the latent space
# * make first seed = last seed to make a LOOP

# %%
pkl_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"

# !python generate.py generate-latent-walk --network={pkl_path} --walk-type="line-w" --seeds=161,1605,70103,80128,161 --outdir="./w-walk2"
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for step 0/244 ...
# Generating image for step 1/244 ...
# Generating image for step 2/244 ...
# Generating image for step 3/244 ...
# Generating image for step 4/244 ...
# Generating image for step 5/244 ...
# Generating image for step 6/244 ...
# Generating image for step 7/244 ...
# Generating image for step 8/244 ...
# Generating image for step 9/244 ...
# Generating image for step 10/244 ...
# Generating image for step 11/244 ...
# Generating image for step 12/244 ...
# Generating image for step 13/244 ...
# Generating image for step 14/244 ...
# Generating image for step 15/244 ...
# Generating image for step 16/244 ...
# Generating image for step 17/244 ...
# Generating image for step 18/244 ...
# Generating image for step 19/244 ...
# Generating image for step 20/244 ...
# Generating image for step 21/244 ...
# Generating image for step 22/244 ...
# Generating image for step 23/244 ...
# Generating image for step 24/244 ...
# Generating image for step 25/244 ...
# Generating image for step 26/244 ...
# Generating image for step 27/244 ...
# Generating image for step 28/244 ...
# Generating image for step 29/244 ...
# Generating image for step 30/244 ...
# Generating image for step 31/244 ...
# Generating image for step 32/244 ...
# Generating image for step 33/244 ...
# Generating image for step 34/244 ...
# Generating image for step 35/244 ...
# Generating image for step 36/244 ...
# Generating image for step 37/244 ...
# Generating image for step 38/244 ...
# Generating image for step 39/244 ...
# Generating image for step 40/244 ...
# Generating image for step 41/244 ...
# Generating image for step 42/244 ...
# Generating image for step 43/244 ...
# Generating image for step 44/244 ...
# Generating image for step 45/244 ...
# Generating image for step 46/244 ...
# Generating image for step 47/244 ...
# Generating image for step 48/244 ...
# Generating image for step 49/244 ...
# Generating image for step 50/244 ...
# Generating image for step 51/244 ...
# Generating image for step 52/244 ...
# Generating image for step 53/244 ...
# Generating image for step 54/244 ...
# Generating image for step 55/244 ...
# Generating image for step 56/244 ...
# Generating image for step 57/244 ...
# Generating image for step 58/244 ...
# Generating image for step 59/244 ...
# Generating image for step 60/244 ...
# Generating image for step 61/244 ...
# Generating image for step 62/244 ...
# Generating image for step 63/244 ...
# Generating image for step 64/244 ...
# Generating image for step 65/244 ...
# Generating image for step 66/244 ...
# Generating image for step 67/244 ...
# Generating image for step 68/244 ...
# Generating image for step 69/244 ...
# Generating image for step 70/244 ...
# Generating image for step 71/244 ...
# Generating image for step 72/244 ...
# Generating image for step 73/244 ...
# Generating image for step 74/244 ...
# Generating image for step 75/244 ...
# Generating image for step 76/244 ...
# Generating image for step 77/244 ...
# Generating image for step 78/244 ...
# Generating image for step 79/244 ...
# Generating image for step 80/244 ...
# Generating image for step 81/244 ...
# Generating image for step 82/244 ...
# Generating image for step 83/244 ...
# Generating image for step 84/244 ...
# Generating image for step 85/244 ...
# Generating image for step 86/244 ...
# Generating image for step 87/244 ...
# Generating image for step 88/244 ...
# Generating image for step 89/244 ...
# Generating image for step 90/244 ...
# Generating image for step 91/244 ...
# Generating image for step 92/244 ...
# Generating image for step 93/244 ...
# Generating image for step 94/244 ...
# Generating image for step 95/244 ...
# Generating image for step 96/244 ...
# Generating image for step 97/244 ...
# Generating image for step 98/244 ...
# Generating image for step 99/244 ...
# Generating image for step 100/244 ...
# Generating image for step 101/244 ...
# Generating image for step 102/244 ...
# Generating image for step 103/244 ...
# Generating image for step 104/244 ...
# Generating image for step 105/244 ...
# Generating image for step 106/244 ...
# Generating image for step 107/244 ...
# Generating image for step 108/244 ...
# Generating image for step 109/244 ...
# Generating image for step 110/244 ...
# Generating image for step 111/244 ...
# Generating image for step 112/244 ...
# Generating image for step 113/244 ...
# Generating image for step 114/244 ...
# Generating image for step 115/244 ...
# Generating image for step 116/244 ...
# Generating image for step 117/244 ...
# Generating image for step 118/244 ...
# Generating image for step 119/244 ...
# Generating image for step 120/244 ...
# Generating image for step 121/244 ...
# Generating image for step 122/244 ...
# Generating image for step 123/244 ...
# Generating image for step 124/244 ...
# Generating image for step 125/244 ...
# Generating image for step 126/244 ...
# Generating image for step 127/244 ...
# Generating image for step 128/244 ...
# Generating image for step 129/244 ...
# Generating image for step 130/244 ...
# Generating image for step 131/244 ...
# Generating image for step 132/244 ...
# Generating image for step 133/244 ...
# Generating image for step 134/244 ...
# Generating image for step 135/244 ...
# Generating image for step 136/244 ...
# Generating image for step 137/244 ...
# Generating image for step 138/244 ...
# Generating image for step 139/244 ...
# Generating image for step 140/244 ...
# Generating image for step 141/244 ...
# Generating image for step 142/244 ...
# Generating image for step 143/244 ...
# Generating image for step 144/244 ...
# Generating image for step 145/244 ...
# Generating image for step 146/244 ...
# Generating image for step 147/244 ...
# Generating image for step 148/244 ...
# Generating image for step 149/244 ...
# Generating image for step 150/244 ...
# Generating image for step 151/244 ...
# Generating image for step 152/244 ...
# Generating image for step 153/244 ...
# Generating image for step 154/244 ...
# Generating image for step 155/244 ...
# Generating image for step 156/244 ...
# Generating image for step 157/244 ...
# Generating image for step 158/244 ...
# Generating image for step 159/244 ...
# Generating image for step 160/244 ...
# Generating image for step 161/244 ...
# Generating image for step 162/244 ...
# Generating image for step 163/244 ...
# Generating image for step 164/244 ...
# Generating image for step 165/244 ...
# Generating image for step 166/244 ...
# Generating image for step 167/244 ...
# Generating image for step 168/244 ...
# Generating image for step 169/244 ...
# Generating image for step 170/244 ...
# Generating image for step 171/244 ...
# Generating image for step 172/244 ...
# Generating image for step 173/244 ...
# Generating image for step 174/244 ...
# Generating image for step 175/244 ...
# Generating image for step 176/244 ...
# Generating image for step 177/244 ...
# Generating image for step 178/244 ...
# Generating image for step 179/244 ...
# Generating image for step 180/244 ...
# Generating image for step 181/244 ...
# Generating image for step 182/244 ...
# Generating image for step 183/244 ...
# Generating image for step 184/244 ...
# Generating image for step 185/244 ...
# Generating image for step 186/244 ...
# Generating image for step 187/244 ...
# Generating image for step 188/244 ...
# Generating image for step 189/244 ...
# Generating image for step 190/244 ...
# Generating image for step 191/244 ...
# Generating image for step 192/244 ...
# Generating image for step 193/244 ...
# Generating image for step 194/244 ...
# Generating image for step 195/244 ...
# Generating image for step 196/244 ...
# Generating image for step 197/244 ...
# Generating image for step 198/244 ...
# Generating image for step 199/244 ...
# Generating image for step 200/244 ...
# Generating image for step 201/244 ...
# Generating image for step 202/244 ...
# Generating image for step 203/244 ...
# Generating image for step 204/244 ...
# Generating image for step 205/244 ...
# Generating image for step 206/244 ...
# Generating image for step 207/244 ...
# Generating image for step 208/244 ...
# Generating image for step 209/244 ...
# Generating image for step 210/244 ...
# Generating image for step 211/244 ...
# Generating image for step 212/244 ...
# Generating image for step 213/244 ...
# Generating image for step 214/244 ...
# Generating image for step 215/244 ...
# Generating image for step 216/244 ...
# Generating image for step 217/244 ...
# Generating image for step 218/244 ...
# Generating image for step 219/244 ...
# Generating image for step 220/244 ...
# Generating image for step 221/244 ...
# Generating image for step 222/244 ...
# Generating image for step 223/244 ...
# Generating image for step 224/244 ...
# Generating image for step 225/244 ...
# Generating image for step 226/244 ...
# Generating image for step 227/244 ...
# Generating image for step 228/244 ...
# Generating image for step 229/244 ...
# Generating image for step 230/244 ...
# Generating image for step 231/244 ...
# Generating image for step 232/244 ...
# Generating image for step 233/244 ...
# Generating image for step 234/244 ...
# Generating image for step 235/244 ...
# Generating image for step 236/244 ...
# Generating image for step 237/244 ...
# Generating image for step 238/244 ...
# Generating image for step 239/244 ...
# Generating image for step 240/244 ...
# Generating image for step 241/244 ...
# Generating image for step 242/244 ...
# Generating image for step 243/244 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './w-walk2/frame%05d.png':
#   Duration: 00:00:09.76, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e54dbfde00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55e54dbfde00] profile High, level 3.0
# [libx264 @ 0x55e54dbfde00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './w-walk2/walk-w-line161-1605-70103-80128-161-24fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  244 fps= 66 q=-1.0 Lsize=    3591kB time=00:00:10.04 bitrate=2929.6kbits/s speed=2.74x
# video:3587kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.101129%
# [libx264 @ 0x55e54dbfde00] frame I:3     Avg QP:24.16  size: 35559
# [libx264 @ 0x55e54dbfde00] frame P:75    Avg QP:28.40  size: 24807
# [libx264 @ 0x55e54dbfde00] frame B:166   Avg QP:32.11  size: 10275
# [libx264 @ 0x55e54dbfde00] consecutive B-frames:  8.6%  1.6%  1.2% 88.5%
# [libx264 @ 0x55e54dbfde00] mb I  I16..4: 18.6% 33.5% 47.9%
# [libx264 @ 0x55e54dbfde00] mb P  I16..4:  2.2%  8.8% 14.1%  P16..4: 14.4% 13.6% 12.1%  0.0%  0.0%    skip:34.8%
# [libx264 @ 0x55e54dbfde00] mb B  I16..4:  0.3%  0.6%  2.2%  B16..8: 15.0% 11.1%  8.2%  direct: 8.0%  skip:54.6%  L0:29.5% L1:35.5% BI:35.0%
# [libx264 @ 0x55e54dbfde00] 8x8 transform intra:31.7% inter:35.2%
# [libx264 @ 0x55e54dbfde00] coded y,uvDC,uvAC intra: 73.1% 72.3% 63.1% inter: 25.5% 19.6% 10.3%
# [libx264 @ 0x55e54dbfde00] i16 v,h,dc,p: 75% 16%  4%  5%
# [libx264 @ 0x55e54dbfde00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27%  8% 37%  5%  4%  7%  4%  5%  4%
# [libx264 @ 0x55e54dbfde00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 14% 14%  8%  7% 10%  7%  7%  6%
# [libx264 @ 0x55e54dbfde00] i8c dc,h,v,p: 51% 14% 27%  9%
# [libx264 @ 0x55e54dbfde00] Weighted P-Frames: Y:4.0% UV:1.3%
# [libx264 @ 0x55e54dbfde00] ref P L0: 67.1% 17.1% 11.5%  4.3%  0.1%
# [libx264 @ 0x55e54dbfde00] ref B L0: 94.1%  4.5%  1.4%
# [libx264 @ 0x55e54dbfde00] ref B L1: 98.5%  1.5%
# [libx264 @ 0x55e54dbfde00] kb/s:2890.11

# %% [markdown]
# ### Noise loop interpolation
#
# Similar to latent walk above, but only set one starting seed and the path will be chosen for you.

# %%
pkl_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"

# !python generate.py generate-latent-walk --network={pkl_path} --walk-type="noiseloop" --start_seed=161 --outdir="./noisel"
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for step 0/240 ...
# Generating image for step 1/240 ...
# Generating image for step 2/240 ...
# Generating image for step 3/240 ...
# Generating image for step 4/240 ...
# Generating image for step 5/240 ...
# Generating image for step 6/240 ...
# Generating image for step 7/240 ...
# Generating image for step 8/240 ...
# Generating image for step 9/240 ...
# Generating image for step 10/240 ...
# Generating image for step 11/240 ...
# Generating image for step 12/240 ...
# Generating image for step 13/240 ...
# Generating image for step 14/240 ...
# Generating image for step 15/240 ...
# Generating image for step 16/240 ...
# Generating image for step 17/240 ...
# Generating image for step 18/240 ...
# Generating image for step 19/240 ...
# Generating image for step 20/240 ...
# Generating image for step 21/240 ...
# Generating image for step 22/240 ...
# Generating image for step 23/240 ...
# Generating image for step 24/240 ...
# Generating image for step 25/240 ...
# Generating image for step 26/240 ...
# Generating image for step 27/240 ...
# Generating image for step 28/240 ...
# Generating image for step 29/240 ...
# Generating image for step 30/240 ...
# Generating image for step 31/240 ...
# Generating image for step 32/240 ...
# Generating image for step 33/240 ...
# Generating image for step 34/240 ...
# Generating image for step 35/240 ...
# Generating image for step 36/240 ...
# Generating image for step 37/240 ...
# Generating image for step 38/240 ...
# Generating image for step 39/240 ...
# Generating image for step 40/240 ...
# Generating image for step 41/240 ...
# Generating image for step 42/240 ...
# Generating image for step 43/240 ...
# Generating image for step 44/240 ...
# Generating image for step 45/240 ...
# Generating image for step 46/240 ...
# Generating image for step 47/240 ...
# Generating image for step 48/240 ...
# Generating image for step 49/240 ...
# Generating image for step 50/240 ...
# Generating image for step 51/240 ...
# Generating image for step 52/240 ...
# Generating image for step 53/240 ...
# Generating image for step 54/240 ...
# Generating image for step 55/240 ...
# Generating image for step 56/240 ...
# Generating image for step 57/240 ...
# Generating image for step 58/240 ...
# Generating image for step 59/240 ...
# Generating image for step 60/240 ...
# Generating image for step 61/240 ...
# Generating image for step 62/240 ...
# Generating image for step 63/240 ...
# Generating image for step 64/240 ...
# Generating image for step 65/240 ...
# Generating image for step 66/240 ...
# Generating image for step 67/240 ...
# Generating image for step 68/240 ...
# Generating image for step 69/240 ...
# Generating image for step 70/240 ...
# Generating image for step 71/240 ...
# Generating image for step 72/240 ...
# Generating image for step 73/240 ...
# Generating image for step 74/240 ...
# Generating image for step 75/240 ...
# Generating image for step 76/240 ...
# Generating image for step 77/240 ...
# Generating image for step 78/240 ...
# Generating image for step 79/240 ...
# Generating image for step 80/240 ...
# Generating image for step 81/240 ...
# Generating image for step 82/240 ...
# Generating image for step 83/240 ...
# Generating image for step 84/240 ...
# Generating image for step 85/240 ...
# Generating image for step 86/240 ...
# Generating image for step 87/240 ...
# Generating image for step 88/240 ...
# Generating image for step 89/240 ...
# Generating image for step 90/240 ...
# Generating image for step 91/240 ...
# Generating image for step 92/240 ...
# Generating image for step 93/240 ...
# Generating image for step 94/240 ...
# Generating image for step 95/240 ...
# Generating image for step 96/240 ...
# Generating image for step 97/240 ...
# Generating image for step 98/240 ...
# Generating image for step 99/240 ...
# Generating image for step 100/240 ...
# Generating image for step 101/240 ...
# Generating image for step 102/240 ...
# Generating image for step 103/240 ...
# Generating image for step 104/240 ...
# Generating image for step 105/240 ...
# Generating image for step 106/240 ...
# Generating image for step 107/240 ...
# Generating image for step 108/240 ...
# Generating image for step 109/240 ...
# Generating image for step 110/240 ...
# Generating image for step 111/240 ...
# Generating image for step 112/240 ...
# Generating image for step 113/240 ...
# Generating image for step 114/240 ...
# Generating image for step 115/240 ...
# Generating image for step 116/240 ...
# Generating image for step 117/240 ...
# Generating image for step 118/240 ...
# Generating image for step 119/240 ...
# Generating image for step 120/240 ...
# Generating image for step 121/240 ...
# Generating image for step 122/240 ...
# Generating image for step 123/240 ...
# Generating image for step 124/240 ...
# Generating image for step 125/240 ...
# Generating image for step 126/240 ...
# Generating image for step 127/240 ...
# Generating image for step 128/240 ...
# Generating image for step 129/240 ...
# Generating image for step 130/240 ...
# Generating image for step 131/240 ...
# Generating image for step 132/240 ...
# Generating image for step 133/240 ...
# Generating image for step 134/240 ...
# Generating image for step 135/240 ...
# Generating image for step 136/240 ...
# Generating image for step 137/240 ...
# Generating image for step 138/240 ...
# Generating image for step 139/240 ...
# Generating image for step 140/240 ...
# Generating image for step 141/240 ...
# Generating image for step 142/240 ...
# Generating image for step 143/240 ...
# Generating image for step 144/240 ...
# Generating image for step 145/240 ...
# Generating image for step 146/240 ...
# Generating image for step 147/240 ...
# Generating image for step 148/240 ...
# Generating image for step 149/240 ...
# Generating image for step 150/240 ...
# Generating image for step 151/240 ...
# Generating image for step 152/240 ...
# Generating image for step 153/240 ...
# Generating image for step 154/240 ...
# Generating image for step 155/240 ...
# Generating image for step 156/240 ...
# Generating image for step 157/240 ...
# Generating image for step 158/240 ...
# Generating image for step 159/240 ...
# Generating image for step 160/240 ...
# Generating image for step 161/240 ...
# Generating image for step 162/240 ...
# Generating image for step 163/240 ...
# Generating image for step 164/240 ...
# Generating image for step 165/240 ...
# Generating image for step 166/240 ...
# Generating image for step 167/240 ...
# Generating image for step 168/240 ...
# Generating image for step 169/240 ...
# Generating image for step 170/240 ...
# Generating image for step 171/240 ...
# Generating image for step 172/240 ...
# Generating image for step 173/240 ...
# Generating image for step 174/240 ...
# Generating image for step 175/240 ...
# Generating image for step 176/240 ...
# Generating image for step 177/240 ...
# Generating image for step 178/240 ...
# Generating image for step 179/240 ...
# Generating image for step 180/240 ...
# Generating image for step 181/240 ...
# Generating image for step 182/240 ...
# Generating image for step 183/240 ...
# Generating image for step 184/240 ...
# Generating image for step 185/240 ...
# Generating image for step 186/240 ...
# Generating image for step 187/240 ...
# Generating image for step 188/240 ...
# Generating image for step 189/240 ...
# Generating image for step 190/240 ...
# Generating image for step 191/240 ...
# Generating image for step 192/240 ...
# Generating image for step 193/240 ...
# Generating image for step 194/240 ...
# Generating image for step 195/240 ...
# Generating image for step 196/240 ...
# Generating image for step 197/240 ...
# Generating image for step 198/240 ...
# Generating image for step 199/240 ...
# Generating image for step 200/240 ...
# Generating image for step 201/240 ...
# Generating image for step 202/240 ...
# Generating image for step 203/240 ...
# Generating image for step 204/240 ...
# Generating image for step 205/240 ...
# Generating image for step 206/240 ...
# Generating image for step 207/240 ...
# Generating image for step 208/240 ...
# Generating image for step 209/240 ...
# Generating image for step 210/240 ...
# Generating image for step 211/240 ...
# Generating image for step 212/240 ...
# Generating image for step 213/240 ...
# Generating image for step 214/240 ...
# Generating image for step 215/240 ...
# Generating image for step 216/240 ...
# Generating image for step 217/240 ...
# Generating image for step 218/240 ...
# Generating image for step 219/240 ...
# Generating image for step 220/240 ...
# Generating image for step 221/240 ...
# Generating image for step 222/240 ...
# Generating image for step 223/240 ...
# Generating image for step 224/240 ...
# Generating image for step 225/240 ...
# Generating image for step 226/240 ...
# Generating image for step 227/240 ...
# Generating image for step 228/240 ...
# Generating image for step 229/240 ...
# Generating image for step 230/240 ...
# Generating image for step 231/240 ...
# Generating image for step 232/240 ...
# Generating image for step 233/240 ...
# Generating image for step 234/240 ...
# Generating image for step 235/240 ...
# Generating image for step 236/240 ...
# Generating image for step 237/240 ...
# Generating image for step 238/240 ...
# Generating image for step 239/240 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './noisel/frame%05d.png':
#   Duration: 00:00:09.60, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5619ba887e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5619ba887e00] profile High, level 3.0
# [libx264 @ 0x5619ba887e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './noisel/walk-z-noiseloop-seed161-24fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  240 fps= 62 q=-1.0 Lsize=    3896kB time=00:00:09.87 bitrate=3231.9kbits/s speed=2.55x
# video:3892kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.087785%
# [libx264 @ 0x5619ba887e00] frame I:5     Avg QP:24.00  size: 32694
# [libx264 @ 0x5619ba887e00] frame P:96    Avg QP:28.97  size: 20855
# [libx264 @ 0x5619ba887e00] frame B:139   Avg QP:31.89  size: 13091
# [libx264 @ 0x5619ba887e00] consecutive B-frames: 21.2%  3.3%  3.8% 71.7%
# [libx264 @ 0x5619ba887e00] mb I  I16..4: 19.2% 34.9% 45.9%
# [libx264 @ 0x5619ba887e00] mb P  I16..4:  2.5%  9.3% 14.6%  P16..4: 17.0% 12.5% 10.9%  0.0%  0.0%    skip:33.3%
# [libx264 @ 0x5619ba887e00] mb B  I16..4:  0.5%  1.0%  4.1%  B16..8: 16.5% 13.8%  9.8%  direct: 8.0%  skip:46.3%  L0:33.9% L1:35.1% BI:31.0%
# [libx264 @ 0x5619ba887e00] 8x8 transform intra:31.7% inter:34.6%
# [libx264 @ 0x5619ba887e00] coded y,uvDC,uvAC intra: 70.8% 66.6% 53.6% inter: 30.7% 21.5% 7.8%
# [libx264 @ 0x5619ba887e00] i16 v,h,dc,p: 75% 15%  5%  6%
# [libx264 @ 0x5619ba887e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37%  7% 32%  5%  3%  5%  4%  4%  4%
# [libx264 @ 0x5619ba887e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 14% 14%  8%  6%  9%  7%  7%  6%
# [libx264 @ 0x5619ba887e00] i8c dc,h,v,p: 53% 15% 25%  8%
# [libx264 @ 0x5619ba887e00] Weighted P-Frames: Y:9.4% UV:5.2%
# [libx264 @ 0x5619ba887e00] ref P L0: 70.8% 16.2%  8.4%  3.8%  0.7%
# [libx264 @ 0x5619ba887e00] ref B L0: 92.9%  4.7%  2.4%
# [libx264 @ 0x5619ba887e00] ref B L1: 98.8%  1.2%
# [libx264 @ 0x5619ba887e00] kb/s:3188.16

# %% [markdown]
# ## Projection
# - take an image from **outside** your dataset and find the closest approximation **in** your dataset
# - if you find an image that is an exact match inside the data it probably means it was generated by the dataset
# - lets you see the interaction of your dataset with data from the wild

# %%
pkl_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"

target = "/content/cbd_05.jpg"

# !python projector.py --outdir="./projection" --target={target} --network={pkl_path}
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Projector: Computing W midpoint and stddev using 10000 samples...
# Projector: std = 16.8972
# Projector: Setting up noise inputs...
# Projector: Building image output graph...
# Projector: Building loss graph...
# Projector: Building noise regularization graph...
# Projector: Setting up optimizer...
# Projector: Preparing target images...
# Projector: Initializing optimization state...
# 100% 1000/1000 [01:45<00:00,  9.47it/s, dist=0.2429, loss=0.24]

# %% [markdown]
# ## Nearest Neighbors
#
# - lets say you have a seed you like, but want to see other images like it to see if there's something better. Now you can with the `near-neighbor` argument
# - `--network`, `--seeds`, and `truncation_psi` work the same as above.
# - `--diameter`: this sets how far away from the seedyou want to generate the images. `.0000001` is really close, `0.5` is really far
# - `--num_samples`: how many samples you want to produce
# - `--save_vector`: this will save the vector as a file in the `.npy` format. You can then use this for interpolation (not super well supported right now, but can be used manually -- see the Projection code for an example of reading an .npy file and interpolating it)

# %%
pkl_path = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"


# !python generate.py generate-neighbors --network={pkl_path} --seeds=161 --num_samples=5 --outdir="./neighbors" --diameter=0.0005
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00021-tarot_os2-mirror-11gb-gpu-gamma35-bg-resumecustom/network-snapshot-000832.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 161 (1/1) ...
